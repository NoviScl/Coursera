# %%
from preprocessed_mnist import load_dataset
X_train, y_train, X_val, y_val, X_test, y_test = load_dataset()
print(X_train.shape, y_train.shape)
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# (50000, 28, 28) (50000,)

# %%
import numpy as np
import tensorflow as tf
import time

# %%
#some gloabel parameters
ntrains = X_train.shape[0]
ntest = X_test.shape[0]
train_index = np.arange(ntrains)
nepoch = 100
batch_size = 256
nbatch= int(50000/batch_size)
image_x,image_y = X_train[0].shape
#number of hidden unit
nhidden=50
nclass =10
#use for regulize
beta = 0.1

# %%
#tf.reshape seems not accept [None,-1], which means we need rehshape
# the image to 1-D array before put into the tensor
input_x = tf.placeholder('float32',shape=(None,image_x*image_y))
# we have 10 classes, the length of one hot vector is 10
input_y = tf.placeholder('float32',shape = [None,nclass])

# %%
#create the hidden layer with 50 hidden units shape: (image_x*image_y,nhidden)
#random to -0.5 to 0.5, random from 0 to 1 can easily run into local minimum
hidden_layer0 = tf.Variable(initial_value=np.random.rand(image_x*image_y,nhidden)-0.5,dtype='float32')
hidden_bias0 = tf.Variable(initial_value=np.zeros((1,nhidden),dtype='float32'))
#create output layer with the shape (nclass,nhidden), 10 is the number of class 
# nhidden is the row of  previous layer
output_layer = tf.Variable(initial_value=np.random.rand(nhidden,nclass)-0.5,dtype='float32')
output_bias = tf.Variable(initial_value=np.zeros((1,nclass),dtype='float32'))

# %%
# do some mathematic to get the predict value
# we take the example as (1,image_x*image_y)
# not column vector
#shape of hidden_value0 : (None,nhidden)
#shape of output_value :(None,nclass)
hidden_value0 = tf.nn.sigmoid(tf.matmul(input_x,hidden_layer0)+hidden_bias0)
#output_value = tf.exp(tf.matmul(hidden_value0,output_layer)+output_bias)
#use softmax version in tenser flow
output_value = tf.matmul(hidden_value0,output_layer)+output_bias
#-1 is the last axis
predict_y = tf.nn.softmax(logits=output_value)

# %%
#loss function, need change the y to one hot vector
#create placeholder for the y_train

#use the tensorflow loss 
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=output_value,labels = input_y))
#add regulizer
regu = tf.reduce_mean(hidden_layer0**2) + tf.reduce_mean(hidden_bias0**2)
regu += tf.reduce_mean(output_layer**2) + tf.reduce_mean(output_bias**2)

loss_regu = loss + beta*regu

# %%
#optimiser AdamOptimizer works better than momentum
optimizer = tf.train.AdamOptimizer().minimize(loss_regu)

# %%
#initailize
init = tf.global_variables_initializer()
#create a session
sess = tf.Session()
sess.run(init)

# %%
#run the tensor
start_time = time.time()

loss_train_list = []
loss_test_list = []
acc_test_list=[]
for i in range(nepoch):
    # we should reorder the train list for each
    #epoch. This will make the minibatch
    #we got more close to the data distribution
    np.random.shuffle(train_index)
    for j in range(nbatch):
        #not the last minibatch
        low = j*batch_size
        up = (j+1)*batch_size;
        #last minibatch
        #if j >= batch_size-1:
        #    up = ntrains
        batch_x = X_train[train_index[low:up]].reshape(up-low,-1)
        #create one hot 
        batch_y = np.eye(10)[y_train[train_index[low:up]]]
        #print(batch_y.shape)
        #start train
        sess.run(optimizer,feed_dict={input_x:batch_x,input_y:batch_y})
        if j == nbatch -1:
            loss_valule_train = sess.run(loss,feed_dict={input_x:batch_x,input_y:batch_y})
            loss_value_test = sess.run(loss,feed_dict={input_x:X_test.reshape(X_test.shape[0],-1),input_y:np.eye(10)[y_test]})
            predict_value = np.argmax(sess.run(predict_y,feed_dict={input_x:X_test.reshape(X_test.shape[0],-1)}),axis=-1)
            accuracy = np.mean(np.abs(np.subtract(predict_value,y_test)) < 0.1)
            predict_value_train = np.argmax(sess.run(predict_y,feed_dict={input_x:batch_x.reshape(up-low,-1)}),axis=-1)
            accuracy_train = np.mean(np.abs(np.subtract(predict_value_train,y_train[train_index[low:up]])) < 0.1)
            loss_train_list.append(loss_valule_train)
            loss_test_list.append(loss_value_test)
            acc_test_list.append(accuracy)
            print("Loss for train: "+str(loss_valule_train))
            print("loss for test: "+str(loss_value_test))
            print("accuracy test: " + str(accuracy))
            print("accuracy train: "+ str(accuracy_train))

print("--- %s seconds ---" % (time.time() - start_time))
plt.figure(1)
plt.plot(loss_train_list)
plt.ylabel("loss train")
plt.figure(2)
plt.plot(acc_test_list)
plt.ylabel("test accuracy")
plt.figure(3)
plt.plot(loss_test_list)
plt.ylabel("loss test")
# Out:
# Loss for train: 0.446464
# loss for test: 0.449283
# accuracy test: 0.8857
# accuracy train: 0.88671875
# Loss for train: 0.316775
# loss for test: 0.327118
# accuracy test: 0.9132
# accuracy train: 0.91015625
# Loss for train: 0.196947
# loss for test: 0.276304
# accuracy test: 0.9232
# accuracy train: 0.9453125
# Loss for train: 0.204938
# loss for test: 0.246425
# accuracy test: 0.9304
# accuracy train: 0.9609375
# Loss for train: 0.233147
# loss for test: 0.224514
# accuracy test: 0.9358
# accuracy train: 0.92578125
# Loss for train: 0.297402
# loss for test: 0.207118
# accuracy test: 0.9412
# accuracy train: 0.9140625
# Loss for train: 0.21609
# loss for test: 0.194424
# accuracy test: 0.9452
# accuracy train: 0.9375
# Loss for train: 0.159334
# loss for test: 0.182248
# accuracy test: 0.9478
# accuracy train: 0.95703125
# Loss for train: 0.23437
# loss for test: 0.173501
# accuracy test: 0.9496
# accuracy train: 0.93359375
# Loss for train: 0.145294
# loss for test: 0.163636
# accuracy test: 0.9531
# accuracy train: 0.96484375
# Loss for train: 0.117429
# loss for test: 0.155587
# accuracy test: 0.9552
# accuracy train: 0.96875
# Loss for train: 0.14409
# loss for test: 0.150707
# accuracy test: 0.9568
# accuracy train: 0.94921875
# Loss for train: 0.120989
# loss for test: 0.144196
# accuracy test: 0.9574
# accuracy train: 0.96484375
# Loss for train: 0.112591
# loss for test: 0.140659
# accuracy test: 0.9595
# accuracy train: 0.9765625
# Loss for train: 0.102652
# loss for test: 0.134823
# accuracy test: 0.9607
# accuracy train: 0.96875
# Loss for train: 0.0976035
# loss for test: 0.129638
# accuracy test: 0.9623
# accuracy train: 0.98046875
# Loss for train: 0.0902753
# loss for test: 0.127488
# accuracy test: 0.9624
# accuracy train: 0.97265625
# Loss for train: 0.130787
# loss for test: 0.121771
# accuracy test: 0.9642
# accuracy train: 0.9609375
# Loss for train: 0.0973072
# loss for test: 0.121247
# accuracy test: 0.9642
# accuracy train: 0.98046875
# Loss for train: 0.0832453
# loss for test: 0.116046
# accuracy test: 0.9654
# accuracy train: 0.97265625
# Loss for train: 0.089486
# loss for test: 0.114092
# accuracy test: 0.9662
# accuracy train: 0.98046875
# Loss for train: 0.0988457
# loss for test: 0.112064
# accuracy test: 0.9672
# accuracy train: 0.96484375
# Loss for train: 0.0999396
# loss for test: 0.108824
# accuracy test: 0.9676
# accuracy train: 0.9765625
# Loss for train: 0.0643284
# loss for test: 0.107437
# accuracy test: 0.9681
# accuracy train: 0.984375
# Loss for train: 0.0516468
# loss for test: 0.105115
# accuracy test: 0.9688
# accuracy train: 0.984375
# Loss for train: 0.0618034
# loss for test: 0.104178
# accuracy test: 0.9687
# accuracy train: 0.9765625
# Loss for train: 0.0441021
# loss for test: 0.101887
# accuracy test: 0.9686
# accuracy train: 0.99609375
# Loss for train: 0.0587979
# loss for test: 0.100315
# accuracy test: 0.9702
# accuracy train: 0.9921875
# Loss for train: 0.0538556
# loss for test: 0.0991099
# accuracy test: 0.9696
# accuracy train: 0.98046875
# Loss for train: 0.0532241
# loss for test: 0.0988996
# accuracy test: 0.9707
# accuracy train: 0.98828125
# Loss for train: 0.0680758
# loss for test: 0.0968897
# accuracy test: 0.9707
# accuracy train: 0.984375
# Loss for train: 0.0532081
# loss for test: 0.0958207
# accuracy test: 0.9717
# accuracy train: 0.984375
# Loss for train: 0.0487053
# loss for test: 0.0972845
# accuracy test: 0.9715
# accuracy train: 0.98828125
# Loss for train: 0.0358863
# loss for test: 0.0941666
# accuracy test: 0.9725
# accuracy train: 0.9921875
# Loss for train: 0.0530498
# loss for test: 0.0932513
# accuracy test: 0.9715
# accuracy train: 0.98828125
# Loss for train: 0.029394
# loss for test: 0.0931964
# accuracy test: 0.972
# accuracy train: 0.9921875
# Loss for train: 0.0398797
# loss for test: 0.0919522
# accuracy test: 0.9724
# accuracy train: 0.98828125
# Loss for train: 0.054344
# loss for test: 0.0910349
# accuracy test: 0.9725
# accuracy train: 0.984375
# Loss for train: 0.0464522
# loss for test: 0.0906847
# accuracy test: 0.9728
# accuracy train: 0.98046875
# Loss for train: 0.0230105
# loss for test: 0.0894632
# accuracy test: 0.9729
# accuracy train: 1.0
# Loss for train: 0.0355928
# loss for test: 0.0888976
# accuracy test: 0.9737
# accuracy train: 1.0
# Loss for train: 0.0389127
# loss for test: 0.088174
# accuracy test: 0.9737
# accuracy train: 0.99609375
# Loss for train: 0.0392598
# loss for test: 0.0876602
# accuracy test: 0.9748
# accuracy train: 0.99609375
# Loss for train: 0.0343269
# loss for test: 0.0881779
# accuracy test: 0.9729
# accuracy train: 0.99609375
# Loss for train: 0.0272314
# loss for test: 0.0883354
# accuracy test: 0.9734
# accuracy train: 0.99609375
# Loss for train: 0.0268568
# loss for test: 0.087311
# accuracy test: 0.9744
# accuracy train: 0.9921875
# Loss for train: 0.0512896
# loss for test: 0.0863789
# accuracy test: 0.9745
# accuracy train: 0.98828125
# Loss for train: 0.0265138
# loss for test: 0.0864583
# accuracy test: 0.9749
# accuracy train: 0.9921875
# Loss for train: 0.0530051
# loss for test: 0.0871226
# accuracy test: 0.9741
# accuracy train: 0.984375
# Loss for train: 0.0395774
# loss for test: 0.0861468
# accuracy test: 0.9747
# accuracy train: 0.98828125
# Loss for train: 0.0250567
# loss for test: 0.0857676
# accuracy test: 0.974
# accuracy train: 1.0
# Loss for train: 0.0255997
# loss for test: 0.0842291
# accuracy test: 0.975
# accuracy train: 1.0
# Loss for train: 0.0221133
# loss for test: 0.0835897
# accuracy test: 0.9756
# accuracy train: 1.0
# Loss for train: 0.0224631
# loss for test: 0.0837191
# accuracy test: 0.9752
# accuracy train: 1.0
# Loss for train: 0.0334377
# loss for test: 0.0831536
# accuracy test: 0.9754
# accuracy train: 0.9921875
# Loss for train: 0.0293119
# loss for test: 0.0847669
# accuracy test: 0.9743
# accuracy train: 0.99609375
# Loss for train: 0.024145
# loss for test: 0.0836523
# accuracy test: 0.9755
# accuracy train: 1.0
# Loss for train: 0.0231988
# loss for test: 0.082621
# accuracy test: 0.975
# accuracy train: 0.9921875
# Loss for train: 0.0239022
# loss for test: 0.0821049
# accuracy test: 0.9753
# accuracy train: 1.0
# Loss for train: 0.0350025
# loss for test: 0.0829467
# accuracy test: 0.9753
# accuracy train: 1.0
# Loss for train: 0.0263887
# loss for test: 0.0818981
# accuracy test: 0.9755
# accuracy train: 0.99609375
# Loss for train: 0.0253951
# loss for test: 0.0817643
# accuracy test: 0.9755
# accuracy train: 0.99609375
# Loss for train: 0.0161471
# loss for test: 0.0818007
# accuracy test: 0.9759
# accuracy train: 1.0
# Loss for train: 0.0451121
# loss for test: 0.0812898
# accuracy test: 0.9761
# accuracy train: 0.99609375
# Loss for train: 0.0188943
# loss for test: 0.0816508
# accuracy test: 0.9756
# accuracy train: 1.0
# Loss for train: 0.0369719
# loss for test: 0.0815103
# accuracy test: 0.9756
# accuracy train: 0.99609375
# Loss for train: 0.0212532
# loss for test: 0.0809077
# accuracy test: 0.9761
# accuracy train: 0.99609375
# Loss for train: 0.0144961
# loss for test: 0.0801031
# accuracy test: 0.9757
# accuracy train: 1.0
# Loss for train: 0.0281594
# loss for test: 0.0802919
# accuracy test: 0.9767
# accuracy train: 1.0
# Loss for train: 0.0270056
# loss for test: 0.080632
# accuracy test: 0.9761
# accuracy train: 0.99609375
# Loss for train: 0.0252506
# loss for test: 0.0803337
# accuracy test: 0.9766
# accuracy train: 0.99609375
# Loss for train: 0.0328611
# loss for test: 0.0804453
# accuracy test: 0.9764
# accuracy train: 0.9921875
# Loss for train: 0.0254531
# loss for test: 0.0797219
# accuracy test: 0.9765
# accuracy train: 0.99609375
# Loss for train: 0.0190321
# loss for test: 0.0813669
# accuracy test: 0.9757
# accuracy train: 1.0
# Loss for train: 0.0205121
# loss for test: 0.0793808
# accuracy test: 0.9764
# accuracy train: 1.0
# Loss for train: 0.014089
# loss for test: 0.0805093
# accuracy test: 0.9761
# accuracy train: 1.0
# Loss for train: 0.0189029
# loss for test: 0.0815201
# accuracy test: 0.9761
# accuracy train: 1.0
# Loss for train: 0.0235751
# loss for test: 0.0799923
# accuracy test: 0.9763
# accuracy train: 1.0
# Loss for train: 0.0194023
# loss for test: 0.0791646
# accuracy test: 0.9762
# accuracy train: 1.0
# Loss for train: 0.0194552
# loss for test: 0.0795714
# accuracy test: 0.9758
# accuracy train: 1.0
# Loss for train: 0.0176868
# loss for test: 0.0798384
# accuracy test: 0.976
# accuracy train: 1.0
# Loss for train: 0.017797
# loss for test: 0.079841
# accuracy test: 0.9759
# accuracy train: 0.99609375
# Loss for train: 0.0218044
# loss for test: 0.0798421
# accuracy test: 0.9762
# accuracy train: 1.0
# Loss for train: 0.0286933
# loss for test: 0.0795381
# accuracy test: 0.9758
# accuracy train: 1.0
# Loss for train: 0.0296073
# loss for test: 0.0788617
# accuracy test: 0.9766
# accuracy train: 0.99609375
# Loss for train: 0.0263293
# loss for test: 0.0790241
# accuracy test: 0.9762
# accuracy train: 0.99609375
# Loss for train: 0.0241804
# loss for test: 0.0784309
# accuracy test: 0.9763
# accuracy train: 0.99609375
# Loss for train: 0.0187336
# loss for test: 0.0792482
# accuracy test: 0.9762
# accuracy train: 1.0
# Loss for train: 0.0198127
# loss for test: 0.0783707
# accuracy test: 0.9764
# accuracy train: 1.0
# Loss for train: 0.0171161
# loss for test: 0.0782645
# accuracy test: 0.9768
# accuracy train: 1.0
# Loss for train: 0.0206253
# loss for test: 0.0779045
# accuracy test: 0.9761
# accuracy train: 1.0
# Loss for train: 0.0147664
# loss for test: 0.0775289
# accuracy test: 0.9765
# accuracy train: 1.0
# Loss for train: 0.0249003
# loss for test: 0.0784268
# accuracy test: 0.9761
# accuracy train: 1.0
# Loss for train: 0.0220249
# loss for test: 0.0782794
# accuracy test: 0.9756
# accuracy train: 1.0
# Loss for train: 0.0232995
# loss for test: 0.0784605
# accuracy test: 0.9761
# accuracy train: 0.99609375
# Loss for train: 0.0250458
# loss for test: 0.0782218
# accuracy test: 0.9764
# accuracy train: 1.0
# Loss for train: 0.0203609
# loss for test: 0.0796581
# accuracy test: 0.9752
# accuracy train: 1.0
# Loss for train: 0.0258519
# loss for test: 0.0777961
# accuracy test: 0.9763
# accuracy train: 1.0
# Loss for train: 0.0233504
# loss for test: 0.0776877
# accuracy test: 0.9769
# accuracy train: 1.0
# Loss for train: 0.0186472
# loss for test: 0.0775979
# accuracy test: 0.9766
# accuracy train: 1.0
# --- 283.9446415901184 seconds ---
